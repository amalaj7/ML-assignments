# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link = 'https://www.flipkart.com/poco-m2-pro-green-greener-64-gb/product-reviews/itm795e36b373b6f?pid=MOBFT7MK3Q89BGWR&lid=LSTMOBFT7MK3Q89BGWRP2OFTB&marketplace=FLIPKART'

# %%
page=requests.get(link)
page
# Out:
# <Response [200]>

# %%
soup=bs(page.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8683fa.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="website" property="og:type"/>
# ...

# %%
names = soup.find_all('p',class_='_3LYOAd _3sxSiS')
names
# Out:
# [<p class="_3LYOAd _3sxSiS">Flipkart Customer</p>,
#  <p class="_3LYOAd _3sxSiS">Kamalesh Shib</p>,
#  <p class="_3LYOAd _3sxSiS">রাকেশ সরদার</p>,
#  <p class="_3LYOAd _3sxSiS">Nandan Neo</p>,
#  <p class="_3LYOAd _3sxSiS">Udit Kumar</p>,
#  <p class="_3LYOAd _3sxSiS">Shubham Nayak</p>,
#  <p class="_3LYOAd _3sxSiS">Yaswanth Chowdary</p>,
#  <p class="_3LYOAd _3sxSiS">tabish  raza</p>,
#  <p class="_3LYOAd _3sxSiS">Chanakiya Varma</p>,
#  <p class="_3LYOAd _3sxSiS">Anmol Abhishek</p>]

# %%
cust_name = []
for i in range(0,len(names)):
    cust_name.append(names[i].get_text())
cust_name
# Out:
# ['Flipkart Customer',
#  'Kamalesh Shib',
#  'রাকেশ সরদার',
#  'Nandan Neo',
#  'Udit Kumar',
#  'Shubham Nayak',
#  'Yaswanth Chowdary',
#  'tabish  raza',
#  'Chanakiya Varma',
#  'Anmol Abhishek']

# %%
title = soup.find_all('p',class_='_2xg6Ul')
title
# Out:
# [<p class="_2xg6Ul">Wonderful</p>,
#  <p class="_2xg6Ul">Simply awesome</p>,
#  <p class="_2xg6Ul">Terrific</p>,
#  <p class="_2xg6Ul">Super!</p>,
#  <p class="_2xg6Ul">Brilliant</p>,
#  <p class="_2xg6Ul">Really Nice</p>,
#  <p class="_2xg6Ul">Value-for-money</p>,
#  <p class="_2xg6Ul">Classy product</p>,
#  <p class="_2xg6Ul">Really Nice</p>,
#  <p class="_2xg6Ul">Excellent</p>]

# %%
review_title = []
for i in range(0,len(title)):
    review_title.append(title[i].get_text())
review_title
# Out:
# ['Wonderful',
#  'Simply awesome',
#  'Terrific',
#  'Super!',
#  'Brilliant',
#  'Really Nice',
#  'Value-for-money',
#  'Classy product',
#  'Really Nice',
#  'Excellent']

# %%
review = soup.find_all("div",class_="qwjRop") 
review
# Out:
# [<div class="qwjRop"><div><div class="">After Use of 3 days i am posting this review  <br/>1. Phone is good at this price range. <br/>2. Battery is  excellent <br/>3. Display i mean quality graphics is not good as      Samsung and Moto <br/>4.Camra is ok but  as expected  48 megapixel <br/>5.  Big Display of  6.7 inch<br/>6. Few app that is bamed by Indian government is pre installed <br/>7. Face look is good and only side mounted finger sensor <br/>8 With phone back cover is provided inside the case only and lamination glass is already there so no need to buy ac...</div><span class="_1EPkIx"><span>READ MORE</span></span></div></div>,
# ...

# %%
review_content = []
for i in range(0,len(review)):
    review_content.append(review[i].get_text())
review_content
# Out:
# ['After Use of 3 days i am posting this review  1. Phone is good at this price range. 2. Battery is  excellent 3. Display i mean quality graphics is not good as      Samsung and Moto 4.Camra is ok but  as expected  48 megapixel 5.  Big Display of  6.7 inch6. Few app that is bamed by Indian government is pre installed 7. Face look is good and only side mounted finger sensor 8 With phone back cover is provided inside the case only and lamination glass is already there so no need to buy ac...READ MORE',
#  'Awesome mobile... Great experience.... Battery backup is great... After full charge I used it 26hrs continuously.....Specially macro camera is superb... Those who likes photography this phone is best in this budget... & I suggest to buy it....READ MORE',
# ...

# %%
cust_name
review_title
review_content
# Out:
# ['After Use of 3 days i am posting this review  1. Phone is good at this price range. 2. Battery is  excellent 3. Display i mean quality graphics is not good as      Samsung and Moto 4.Camra is ok but  as expected  48 megapixel 5.  Big Display of  6.7 inch6. Few app that is bamed by Indian government is pre installed 7. Face look is good and only side mounted finger sensor 8 With phone back cover is provided inside the case only and lamination glass is already there so no need to buy ac...READ MORE',
#  'Awesome mobile... Great experience.... Battery backup is great... After full charge I used it 26hrs continuously.....Specially macro camera is superb... Those who likes photography this phone is best in this budget... & I suggest to buy it....READ MORE',
# ...

# %%
df = pd.DataFrame()

# %%
df['Name']=cust_name
df['Review title']=review_title
df['Reviews']=review_content

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# Z:\Anaconda Framework\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                 Name     Review title                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Reviews
# ...
